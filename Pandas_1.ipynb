# %% [markdown]
# # Pandas

# %% [markdown]
# *   Pandas is a powerfull python open source library used for data analysis and data manipulation
# *   Reading and writing data structure and diffrent format like csv ,json, tsv,zip,xml,etc

# %% [markdown]
# # Pandas Data Structure

# %% [markdown]
# 1.   Series
# 2.   DataFrame
# 3.   panel

# %%
# Series : one Dimensionallabel homogenious  Array
# Homogeneous mean the same data type.
# Hetrogeneous mean diffrent data type
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
list_s=[1,2,3,4,'data']
print(list_s)
# Out:
# [1, 2, 3, 4, 'data']

# %%
series=pd.Series(list_s)
series
# Out:
# 0       1
# 1       2
# 2       3
# 3       4
# 4    data
# dtype: object

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
series1=pd.Series([33,5,3,21])
print(series1)
# Out:
# 0    33
# 1     5
# 2     3
# 3    21
# dtype: int64

# %%
series2=pd.Series(['Zeeshan','Khattak','Ml Engineer'],['A','B','C'])
print(series2)
# Out:
# A        Zeeshan
# B        Khattak
# C    Ml Engineer
# dtype: object

# %%
# Create Series using Dictionary
dict_s=pd.Series({'a':1,'b':2})
print(dict_s)
# Out:
# a    1
# b    2
# dtype: int64

# %% [markdown]
# # DataFrame

# %% [markdown]
# Pandas dataframe is two dimensional ,size-mutable ,potentionally hetrogenious tebular data structure with label axis rows and columns

# %%
# how to create pandas DataFrame
empty_df=pd.DataFrame()
print(empty_df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# lst=['a','b','c']
# df=pd.DataFrame(lst)
# df

# %%
ls_1=[[1,2,3],[3,4,5],[11,2,33]]
print(ls_1)
# Out:
# [[1, 2, 3], [3, 4, 5], [11, 2, 33]]

# %%
df=pd.DataFrame(ls_1)
df
# Out:
#     0  1   2
# 0   1  2   3
# 1   3  4   5
# 2  11  2  33

# %%
# Create Dataframe using Dictionary
dic1={'Name':['Zeeshan','Ahmad','Khan','Maryam','Ayisha'],
      'Marks':[89,90,78,90,87]
      }

df=pd.DataFrame(dic1)
df
# Out:
#       Name  Marks
# 0  Zeeshan     89
# 1    Ahmad     90
# 2     Khan     78
# 3   Maryam     90
# 4   Ayisha     87

# %%
# how to read csv file
import pandas as pd
df=pd.read_csv('Orders.csv')
df
# Out:
#     Order ID  Order Date CustomerName             State     City
# 0    B-26055  10-03-2018    Harivansh     Uttar Pradesh  Mathura
# 1    B-25993  03-02-2018       Madhav             Delhi    Delhi
# 2    B-25973  24-01-2018  Madan Mohan     Uttar Pradesh  Mathura
# 3    B-25923  27-12-2018        Gopal       Maharashtra   Mumbai
# 4    B-25757  21-08-2018     Vishakha    Madhya Pradesh   Indore
# ..       ...         ...          ...               ...      ...
# 495  B-25742  03-08-2018       Ashwin               Goa      Goa
# 496  B-26088  26-03-2018       Bhavna            Sikkim  Gangtok
# 497  B-25707  01-07-2018      Shivani       Maharashtra   Mumbai
# 498  B-25758  22-08-2018      Shubham  Himachal Pradesh    Simla
# 499  B-26095  28-03-2018      Monisha         Rajasthan   Jaipur
#
# [500 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
import os  # check where your current directory present

print(os.getcwd())
# Out:
# /content

# %%
# how to Write csv file
df=pd.read_csv('data.csv')
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
# cheack columns name
df.columns
# Out:
# Index(['ID', 'Name', 'Industry', 'Inception', 'Revenue', 'Expenses', 'Profit',
#        'Growth'],
#       dtype='object')

# %%
# print 1st and 2nd columns
df=pd.read_csv('data.csv',usecols=[0,1])
df
# Out:
#    ID             Name
# 0   1          Lamtone
# 1   2        Stripfind
# 2   3  Canecorporation
# 3   4         Mattouch
# 4   5        Techdrill
# 5   6         Techline
# 6   7          Cityace
# 7   8   Kayelectronics
# 8   9          Ganzlax
# 9  10      Trantraxlax
